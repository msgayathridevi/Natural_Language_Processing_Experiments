# %% [markdown]
# # **POS tags for words (With pipeline)**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.chunk import ne_chunk
import string
from nltk.tag import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

df = pd.read_csv("/content/Twitter_Data2 (1).csv")

documents=[]
column_name = "clean_text"
for value in df[column_name]:
    documents.append(value)

# print(documents)
# print(documents[0])

ct=df["clean_text"].values.tolist()
documents = [x for x in ct if str(x) != 'nan']

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
terms = vectorizer.get_feature_names_out()
tfidf_scores = tfidf_matrix.toarray()
df_tfidf = pd.DataFrame(tfidf_scores, columns=terms)


def preprocess_and_pos_tags(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    stemmer = SnowballStemmer('english')
    lemmatizer = WordNetLemmatizer()
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    cleaned_tokens = [token for token in lemmatized_tokens
            if not token.isdigit() and not token in string.punctuation]
    lowercase_tokens = [token.lower() for token in cleaned_tokens]
    pos_tags = pos_tag(lowercase_tokens)
    named_entities = ne_chunk(pos_tags)

    verbs = [word for word, pos in pos_tags if pos.startswith('VB')]
    nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
    adverbs = [word for word, pos in pos_tags if pos.startswith('RB')]
    adjectives = [word for word, pos in pos_tags if pos.startswith('JJ')]

    # print the preprocessed text
    print("Original text:", text)
    print("Preprocessed tokens:", lowercase_tokens)
    print("POS tags:", pos_tags)
    print("Named entities:", named_entities)

    print("Verbs:", verbs)
    print("Nouns:", nouns)
    print("Adverbs:", adverbs)
    print("Adjectives:", adjectives)

for i, doc in enumerate(documents):
    print(f"Document {i+1}:")

    preprocess_and_pos_tags(documents[i])
    print("     tfid    ")
    doc_tfidf = df_tfidf.iloc[i]
    doc_tfidf = doc_tfidf[doc_tfidf != 0]  # Remove terms with TF-IDF score of 0
    print(doc_tfidf)
    print()
    print("---------------xxxxxxxxxxxxxxxxxxxxx--------------------")


print("overall cosine similarity")
print(df_tfidf)

similarity_matrix = cosine_similarity(df_tfidf)
print("cosine similarity for all docs")
print(similarity_matrix)
similarity_matrix.shape

# %% [markdown]
# # **Without pipeline**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.chunk import ne_chunk
import string
from nltk.tag import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

df = pd.read_csv("/content/Twitter_Data2 (1).csv")

documents=[]
column_name = "clean_text"
for value in df[column_name]:
    documents.append(value)

# print(documents)
# print(documents[0])

ct=df["clean_text"].values.tolist()
documents = [x for x in ct if str(x) != 'nan']

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
terms = vectorizer.get_feature_names_out()
tfidf_scores = tfidf_matrix.toarray()
df_tfidf = pd.DataFrame(tfidf_scores, columns=terms)


def preprocess_and_pos_tags(text):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    named_entities = ne_chunk(pos_tags)

    # verbs = [word for word, pos in pos_tags if pos.startswith('VB')]
    # nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
    # adverbs = [word for word, pos in pos_tags if pos.startswith('RB')]
    # adjectives = [word for word, pos in pos_tags if pos.startswith('JJ')]

    print("POS tags:", tokens)

    # print("Verbs:", verbs)
    # print("Nouns:", nouns)
    # print("Adverbs:", adverbs)
    # print("Adjectives:", adjectives)

for i, doc in enumerate(documents):
    print(f"Document {i+1}:")

    preprocess_and_pos_tags(documents[i])
    print("     tfid    ")
    doc_tfidf = df_tfidf.iloc[i]
    doc_tfidf = doc_tfidf[doc_tfidf != 0]  # Remove terms with TF-IDF score of 0
    print(doc_tfidf)
    print()
    print("---------------xxxxxxxxxxxxxxxxxxxxx--------------------")

print("overall cosine similarity")
print(df_tfidf)

similarity_matrix = cosine_similarity(df_tfidf)
print("cosine similarity for all docs")
print(similarity_matrix)
similarity_matrix.shape
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Document 1:
# POS tags: ['talk', 'all', 'the', 'nonsense', 'and', 'continue', 'all', 'the', 'drama', 'will', 'vote', 'for', 'modi']
#      tfid
# all         0.518202
# and         0.173166
# continue    0.349752
# drama       0.349752
# for         0.173166
# modi        0.108994
# nonsense    0.349752
# talk        0.316296
# the         0.289423
# vote        0.183494
# will        0.274145
# Name: 0, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 2:
# POS tags: ['what', 'did', 'just', 'say', 'vote', 'for', 'modi', 'welcome', 'bjp', 'told', 'you', 'rahul', 'the', 'main', 'campaigner', 'for', 'modi', 'think', 'modi', 'should', 'just', 'relax']
#      tfid
# bjp           0.196892
# campaigner    0.251193
# did           0.210116
# for           0.248737
# just          0.420232
# main          0.251193
# modi          0.234840
# rahul         0.227165
# relax         0.251193
# say           0.227165
# should        0.227165
# the           0.103932
# think         0.227165
# told          0.251193
# vote          0.131786
# welcome       0.251193
# what          0.186087
# you           0.196892
# Name: 1, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 3:
# POS tags: ['asking', 'his', 'supporters', 'prefix', 'chowkidar', 'their', 'names', 'modi', 'did', 'great', 'service', 'now', 'there', 'confusion', 'what', 'read', 'what', 'not', 'now', 'crustal', 'clear', 'what', 'will', 'crass', 'filthy', 'nonsensical', 'see', 'how', 'most', 'abuses', 'are', 'coming', 'from', 'chowkidars']
#      tfid
# abuses         0.178064
# are            0.119827
# asking         0.178064
# chowkidar      0.161031
# chowkidars     0.178064
# clear          0.161031
# coming         0.178064
# confusion      0.178064
# crass          0.178064
# crustal        0.178064
# did            0.148945
# filthy         0.178064
# from           0.148945
# great          0.161031
# his            0.139571
# how            0.161031
# modi           0.055490
# most           0.148945
# names          0.178064
# nonsensical    0.178064
# not            0.106449
# now            0.279143
# prefix         0.178064
# read           0.178064
# see            0.178064
# service        0.178064
# supporters     0.161031
# their          0.178064
# there          0.161031
# what           0.395737
# will           0.139571
# Name: 2, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 4:
# POS tags: ['answer', 'who', 'among', 'these', 'the', 'most', 'powerful', 'world', 'leader', 'today', 'trump', 'putin', 'modi', 'may']
#      tfid
# among       0.304296
# answer      0.304296
# leader      0.304296
# may         0.275188
# modi        0.094828
# most        0.254535
# powerful    0.304296
# putin       0.304296
# the         0.125904
# these       0.254535
# today       0.275188
# trump       0.304296
# who         0.214360
# world       0.304296
# Name: 3, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 5:
# POS tags: ['kiya', 'tho', 'refresh', 'maarkefir', 'comment', 'karo']
#      tfid
# comment      0.408248
# karo         0.408248
# kiya         0.408248
# maarkefir    0.408248
# refresh      0.408248
# tho          0.408248
# Name: 4, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 6:
# POS tags: ['surat', 'women', 'perform', 'yagna', 'seeks', 'divine', 'grace', 'for', 'narendra', 'modi', 'become', 'again']
#      tfid
# again       0.316916
# become      0.316916
# divine      0.316916
# for         0.156908
# grace       0.316916
# modi        0.098761
# narendra    0.248407
# perform     0.316916
# seeks       0.316916
# surat       0.316916
# women       0.316916
# yagna       0.316916
# Name: 5, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 7:
# POS tags: ['this', 'comes', 'from', 'cabinet', 'which', 'has', 'scholars', 'like', 'modi', 'smriti', 'and', 'hema', 'time', 'introspect']
#      tfid
# and           0.157464
# cabinet       0.266030
# comes         0.318039
# from          0.266030
# has           0.214022
# hema          0.318039
# introspect    0.318039
# like          0.266030
# modi          0.099111
# scholars      0.318039
# smriti        0.318039
# this          0.172032
# time          0.266030
# which         0.318039
# Name: 6, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 8:
# POS tags: ['with', 'upcoming', 'election', 'india', 'saga', 'going', 'important', 'pair', 'look', 'current', 'modi', 'leads', 'govt', 'elected', 'with', 'deal', 'brexit', 'combination', 'this', 'weekly', 'looks', 'juicy', 'bears', 'imho']
#      tfid
# bears          0.220872
# brexit         0.220872
# combination    0.220872
# current        0.199744
# deal           0.220872
# elected        0.220872
# election       0.184753
# going          0.220872
# govt           0.173125
# imho           0.220872
# important      0.220872
# india          0.123335
# juicy          0.220872
# leads          0.220872
# look           0.220872
# looks          0.220872
# modi           0.068831
# pair           0.220872
# saga           0.220872
# this           0.119473
# upcoming       0.220872
# weekly         0.220872
# with           0.284993
# Name: 7, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 9:
# POS tags: ['gandhi', 'was', 'gay', 'does', 'modi']
#      tfid
# does      0.523717
# gandhi    0.523717
# gay       0.523717
# modi      0.163207
# was       0.387976
# Name: 8, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 10:
# POS tags: ['things', 'like', 'demonetisation', 'gst', 'goods', 'and', 'services', 'tax…the', 'upper', 'castes', 'would', 'sort', 'either', 'view', 'favourably', 'say', 'that', 'need', 'give', 'this', 'more', 'time', 'other', 'castes', 'like', 'dalits', 'the', 'muslims', 'were', 'more', 'against', 'because', 'that', '’', 'just', 'not', 'modi', '’', 'constituency2']
#      tfid
# against           0.125535
# and               0.083899
# because           0.169456
# castes            0.338912
# constituency2     0.169456
# dalits            0.169456
# demonetisation    0.169456
# either            0.169456
# favourably        0.169456
# give              0.153246
# goods             0.169456
# gst               0.153246
# just              0.141745
# like              0.283490
# modi              0.052808
# more              0.306492
# muslims           0.169456
# need              0.132824
# not               0.101303
# other             0.132824
# say               0.153246
# services          0.169456
# sort              0.169456
# tax               0.169456
# that              0.228068
# the               0.140226
# things            0.153246
# this              0.091661
# time              0.141745
# upper             0.169456
# view              0.169456
# were              0.169456
# would             0.153246
# Name: 9, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 11:
# POS tags: ['hope', 'tuthukudi', 'people', 'would', 'prefer', 'honest', 'well', 'behaved', 'nationalist', 'courageous', 'likly', 'minister', 'modi', 'cabinet', 'vote', 'benifit', 'thuthukudi']
#      tfid
# behaved        0.267680
# benifit        0.267680
# cabinet        0.223907
# courageous     0.267680
# honest         0.267680
# hope           0.267680
# likly          0.267680
# minister       0.242074
# modi           0.083418
# nationalist    0.267680
# people         0.198301
# prefer         0.267680
# thuthukudi     0.267680
# tuthukudi      0.267680
# vote           0.140435
# well           0.223907
# would          0.242074
# Name: 10, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 12:
# POS tags: ['calm', 'waters', 'wheres', 'the', 'modi', 'wave']
#      tfid
# calm      0.484030
# modi      0.150839
# the       0.200269
# waters    0.484030
# wave      0.484030
# wheres    0.484030
# Name: 11, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 13:
# POS tags: ['one', 'vote', 'can', 'make', 'all', 'the', 'difference', 'anil', 'kapoor', 'answers', 'modis', 'election', '2019', 'clarion', 'call', 'extends', 'support', 'his', 'vote', 'kar', 'campaign']
#      tfid
# 2019          0.208476
# all           0.197036
# anil          0.240530
# answers       0.240530
# call          0.240530
# campaign      0.222478
# can           0.208476
# clarion       0.240530
# difference    0.240530
# election      0.222478
# extends       0.240530
# his           0.208476
# kapoor        0.240530
# kar           0.240530
# make          0.240530
# modis         0.197036
# one           0.197036
# support       0.208476
# the           0.110047
# vote          0.279079
# Name: 12, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 14:
# POS tags: ['one', 'vote', 'can', 'make', 'all', 'the', 'difference', 'anil', 'kapoor', 'answers', 'modis', 'election', '2019', 'clarion', 'call', 'extends', 'support', 'his', 'campaign']
#      tfid
# 2019          0.221767
# all           0.209597
# anil          0.255864
# answers       0.255864
# call          0.255864
# campaign      0.236661
# can           0.221767
# clarion       0.255864
# difference    0.255864
# election      0.236661
# extends       0.255864
# his           0.221767
# kapoor        0.255864
# make          0.255864
# modis         0.209597
# one           0.209597
# support       0.221767
# the           0.117063
# vote          0.148435
# Name: 13, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 15:
# POS tags: ['vote', 'such', 'party', 'and', 'leadershipwho', 'can', 'take', 'fast', 'and', 'firm', 'action', 'none', 'other', 'than', 'narendra', 'damodardas', 'modi', 'and', 'bjp', 'party']
#      tfid
# action           0.222900
# and              0.366100
# bjp              0.193195
# can              0.193195
# damodardas       0.246477
# fast             0.246477
# firm             0.222900
# leadershipwho    0.246477
# modi             0.076810
# narendra         0.193195
# none             0.246477
# other            0.193195
# party            0.445799
# such             0.206171
# take             0.222900
# than             0.246477
# vote             0.129312
# Name: 14, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 16:
# POS tags: ['vote', 'modi', 'who', 'has', 'not', 'created', 'jobs']
#      tfid
# created    0.521369
# has        0.350851
# jobs       0.521369
# modi       0.162475
# not        0.311680
# vote       0.273530
# who        0.367276
# Name: 15, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 17:
# POS tags: ['through', 'our', 'vote', 'ensure', 'govt', 'need', 'and', 'deserve', 'anupam', 'kher', 'responds', 'modis', 'appeal', 'for', 'the', '2019', 'elections']
#      tfid
# 2019         0.243434
# and          0.153767
# anupam       0.280863
# appeal       0.280863
# deserve      0.280863
# elections    0.280863
# ensure       0.259784
# for          0.153767
# govt         0.243434
# kher         0.280863
# modis        0.230075
# need         0.243434
# our          0.243434
# responds     0.280863
# the          0.128500
# through      0.280863
# vote         0.162938
# Name: 16, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 18:
# POS tags: ['dont', 'play', 'with', 'the', 'words', 'was', 'talking', 'about', 'the', 'modi', 'swamy', 'relation', 'guru', 'saying', 'what', 'good', 'and', 'chowkidar', 'protecting', 'the', 'good', 'mind', 'you', 'tweeted', 'dark', 'side', 'terrorism', 'there', 'any', 'brighter', 'side', 'you', 'better', 'know', 'there', 'any']
#      tfid
# about         0.122675
# and           0.081988
# any           0.299510
# better        0.165596
# brighter      0.165596
# chowkidar     0.149755
# dark          0.165596
# dont          0.129798
# good          0.299510
# guru          0.165596
# know          0.165596
# mind          0.165596
# modi          0.051605
# play          0.165596
# protecting    0.165596
# relation      0.165596
# saying        0.149755
# side          0.331191
# swamy         0.165596
# talking       0.165596
# terrorism     0.165596
# the           0.205548
# there         0.299510
# tweeted       0.165596
# was           0.122675
# what          0.122675
# with          0.106835
# words         0.165596
# you           0.259596
# Name: 17, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 19:
# POS tags: ['was', 'the', 'one', 'who', 'recently', 'said', 'that', 'people', 'who', 'vote', 'against', 'modi', 'are', 'anti', 'national', 'that', 'put', 'gen', 'hooda', 'all', 'congress', 'supporters', 'and', 'those', 'jawans', 'who', 'not', 'support', 'modi', 'anti', 'national', 'what', 'great', 'things', 'did', 'you', 'hear', 'about', 'him']
#      tfid
# about         0.130324
# against       0.130324
# all           0.130324
# and           0.087100
# anti          0.318185
# are           0.118384
# congress      0.147153
# did           0.147153
# gen           0.175921
# great         0.159092
# hear          0.175921
# him           0.137891
# hooda         0.175921
# jawans        0.175921
# modi          0.109645
# national      0.351841
# not           0.105167
# one           0.130324
# people        0.130324
# put           0.175921
# recently      0.159092
# said          0.159092
# support       0.137891
# supporters    0.159092
# that          0.236769
# the           0.072788
# things        0.159092
# those         0.147153
# vote          0.092295
# was           0.130324
# what          0.130324
# who           0.371779
# you           0.137891
# Name: 18, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 20:
# POS tags: ['with', 'firm', 'belief', 'the', 'leadership', 'shri', 'narendra', 'modi', 'bjp', 'entering', 'into', 'politics', 'given', 'form', 'file', 'nomination', 'for', 'the', 'khammam', 'parliamentary', 'seat', 'proceeding', 'khammam', 'today']
#      tfid
# belief           0.218513
# bjp              0.171276
# entering         0.218513
# file             0.218513
# firm             0.197610
# for              0.108188
# form             0.218513
# given            0.197610
# into             0.218513
# khammam          0.437026
# leadership       0.218513
# modi             0.068096
# narendra         0.171276
# nomination       0.218513
# parliamentary    0.218513
# politics         0.218513
# proceeding       0.218513
# seat             0.218513
# shri             0.197610
# the              0.180821
# today            0.197610
# with             0.140974
# Name: 19, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 21:
# POS tags: ['crush', 'jaws', 'those', 'who', 'shoutmodimodi', 'says', 'jds', 'mla', 'this', 'inciting', 'murder']
#      tfid
# crush            0.324639
# inciting         0.324639
# jaws             0.324639
# jds              0.324639
# mla              0.324639
# murder           0.324639
# says             0.324639
# shoutmodimodi    0.324639
# this             0.175602
# those            0.271551
# who              0.228690
# Name: 20, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 22:
# POS tags: ['sultanpur', 'uttar', 'pradesh', 'loksabha', 'candidate', 'select', 'pawan', 'kumar', 'pandey', 'actually', 'public', 'want', 'given', 'vote', 'modi', 'but', 'your', 'current', 'condidate', 'not', 'popular', 'district', 'your', 'candidate', 'bsp', 'candidate', 'sonbhadra', 'singh']
#      tfid
# actually     0.177154
# bsp          0.177154
# but          0.148184
# candidate    0.531462
# condidate    0.177154
# current      0.160208
# district     0.177154
# given        0.160208
# kumar        0.177154
# loksabha     0.177154
# modi         0.055207
# not          0.105905
# pandey       0.177154
# pawan        0.177154
# popular      0.177154
# pradesh      0.177154
# public       0.177154
# select       0.177154
# singh        0.177154
# sonbhadra    0.177154
# sultanpur    0.177154
# uttar        0.177154
# vote         0.092942
# want         0.177154
# your         0.296368
# Name: 21, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 23:
# POS tags: ['thiugh', 'nehru', 'not', 'alive', 'but', 'still', 'alive', 'heart', 'modi', 'for', 'every', 'failure', 'nehru', 'responsible']
#      tfid
# alive          0.509659
# but            0.213157
# every          0.254829
# failure        0.254829
# for            0.126169
# heart          0.254829
# modi           0.079413
# nehru          0.509659
# not            0.152340
# responsible    0.254829
# still          0.254829
# thiugh         0.254829
# Name: 22, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 24:
# POS tags: ['has', 'already', 'taken', 'notice', 'and', 'ordered', 'probe', 'now', 'time', 'for', 'modi', 'take', 'notice', 'muslim', 'family', 'being', 'harassed', 'beaten', 'recently', 'extremist', 'hindus', 'and', 'was', 'suggested', 'leave', 'india', 'move', 'pakistan']
#      tfid
# already      0.206035
# and          0.204020
# beaten       0.206035
# being        0.172342
# extremist    0.206035
# family       0.186326
# for          0.102010
# harassed     0.206035
# has          0.138649
# hindus       0.186326
# india        0.115050
# leave        0.206035
# modi         0.064207
# move         0.206035
# muslim       0.206035
# notice       0.412069
# now          0.161495
# ordered      0.206035
# pakistan     0.186326
# probe        0.206035
# recently     0.186326
# suggested    0.206035
# take         0.186326
# taken        0.186326
# time         0.172342
# was          0.152633
# Name: 23, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 25:
# POS tags: ['was', 'waiting', 'for', 'this', 'modi', 'will', 'also', 'talk', 'about', 'varanasi']
#      tfid
# about       0.298369
# also        0.402759
# for         0.199410
# modi        0.125513
# talk        0.364232
# this        0.217859
# varanasi    0.402759
# waiting     0.402759
# was         0.298369
# will        0.315693
# Name: 24, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 26:
# POS tags: ['according', 'yogi', 'imran', 'masood', 'kin', 'azhar', 'masood', 'according', 'this', 'logic', 'nirav', 'modi', 'lalit', 'modi', 'and', 'narendra', 'modi', 'are', 'brothers', 'from', 'the', 'same', 'mother']
#      tfid
# according    0.432845
# and          0.107153
# are          0.145640
# azhar        0.216423
# brothers     0.216423
# from         0.181031
# imran        0.216423
# kin          0.216423
# lalit        0.216423
# logic        0.216423
# masood       0.432845
# modi         0.202333
# mother       0.216423
# narendra     0.169638
# nirav        0.216423
# same         0.216423
# the          0.089546
# this         0.117066
# yogi         0.216423
# Name: 25, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 27:
# POS tags: ['agree', 'but', 'only', 'during', 'the', 'tenure', 'modiganga', 'rejuvenation', 'works', 'have', 'started', 'working']
#      tfid
# agree           0.310260
# but             0.259523
# during          0.310260
# have            0.259523
# modiganga       0.310260
# only            0.280581
# rejuvenation    0.310260
# started         0.310260
# tenure          0.310260
# the             0.128371
# working         0.310260
# works           0.310260
# Name: 26, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 28:
# POS tags: ['the', 'three', 'codes', 'modi', 'cracked', 'give', 'india', 'huge', 'foreign', 'policy', 'jumpstart', 'via']
#      tfid
# codes        0.331540
# cracked      0.331540
# foreign      0.331540
# give         0.299825
# huge         0.331540
# india        0.185132
# jumpstart    0.331540
# modi         0.103318
# policy       0.331540
# the          0.137176
# three        0.331540
# via          0.277323
# Name: 27, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 29:
# POS tags: ['through', 'our', 'vote', 'ensure', 'govt', 'need', 'and', 'deserve', 'anupam', 'kher', 'responds', 'modis', 'vote', 'kar', 'appeal', 'for', 'the', '2019', 'elections']
#      tfid
# 2019         0.226166
# and          0.142860
# anupam       0.260940
# appeal       0.260940
# deserve      0.260940
# elections    0.260940
# ensure       0.241356
# for          0.142860
# govt         0.226166
# kar          0.260940
# kher         0.260940
# modis        0.213755
# need         0.226166
# our          0.226166
# responds     0.260940
# the          0.119385
# through      0.260940
# vote         0.302760
# Name: 28, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 30:
# POS tags: ['modi', 'govts', 'slashing', 'indias', 'education', 'budget', 'clear', 'indicator', 'that', 'they', 'dont', 'care', 'for', 'indias', 'future', 'congress', 'president', 'shri', 'the', 'other', 'hand', 'has', 'ensured', 'the', 'increase', 'the', 'budget', 'gdp', 'this', 'the', 'future', 'india', 'deserves']
#      tfid
# budget       0.359906
# care         0.179953
# clear        0.162739
# congress     0.150525
# deserves     0.179953
# dont         0.141052
# education    0.162739
# ensured      0.179953
# for          0.089096
# future       0.359906
# gdp          0.179953
# govts        0.162739
# hand         0.179953
# has          0.121098
# increase     0.179953
# india        0.100486
# indias       0.325478
# indicator    0.179953
# modi         0.056079
# other        0.141052
# president    0.179953
# shri         0.162739
# slashing     0.179953
# that         0.121098
# the          0.297825
# they         0.162739
# this         0.097339
# Name: 29, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 31:
# POS tags: ['being', 'born', 'religion', 'where', 'female', 'deities', 'worshipped', 'its', 'misogynistic', 'sadistic', 'tradition', 'and', 'totally', 'against', 'point', 'isits', 'man', 'made', 'tradition', 'and', 'not', 'written', 'one', 'not', 'religious', 'lunatic', 'support', 'own', 'religion', 'its', 'repressive']
#      tfid
# against         0.131049
# and             0.175169
# being           0.147971
# born            0.176899
# deities         0.176899
# female          0.176899
# isits           0.176899
# its             0.295942
# lunatic         0.176899
# made            0.147971
# man             0.159977
# misogynistic    0.176899
# not             0.211504
# one             0.131049
# own             0.159977
# point           0.176899
# religion        0.353798
# religious       0.176899
# repressive      0.176899
# sadistic        0.176899
# support         0.138658
# totally         0.176899
# tradition       0.353798
# where           0.176899
# worshipped      0.176899
# written         0.176899
# Name: 30, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 32:
# POS tags: ['how', 'such', 'people', 'are', 'being', 'made', 'amazedn', 'fear', 'that', 'frustation', 'him', 'may', 'not', 'result', 'vote', 'against', 'sir', 'waste', 'ministerdisgrace', 'entire', 'modi', 'cabinet']
#      tfid
# against             0.187565
# amazedn             0.253188
# are                 0.170380
# being               0.211784
# cabinet             0.211784
# entire              0.253188
# fear                0.253188
# frustation          0.253188
# him                 0.198455
# how                 0.228968
# made                0.211784
# may                 0.228968
# ministerdisgrace    0.253188
# modi                0.078901
# not                 0.151358
# people              0.187565
# result              0.253188
# sir                 0.228968
# such                0.211784
# that                0.170380
# vote                0.132832
# waste               0.253188
# Name: 31, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 33:
# POS tags: ['only', 'modi']
#      tfid
# modi    0.325794
# only    0.945441
# Name: 32, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 34:
# POS tags: ['check', 'out', 'latest', 'article', 'premier', 'archery', 'league', 'via']
#      tfid
# archery    0.364723
# article    0.364723
# check      0.364723
# latest     0.364723
# league     0.364723
# out        0.329834
# premier    0.364723
# via        0.305080
# Name: 33, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 35:
# POS tags: ['india', 'second', 'most', 'optimistic', 'globally', 'about', 'executive', 'job', 'growth', 'shows', 'the', 'survey', 'indias', 'senior', 'executives', 'said', 'that', 'they', 'are', 'optimistic', 'about', 'the', 'growth', 'the', 'number', 'job', 'roles', 'this', 'year']
#      tfid
# about         0.275056
# are           0.124928
# executive     0.185645
# executives    0.185645
# globally      0.185645
# growth        0.371290
# india         0.103664
# indias        0.167886
# job           0.310573
# most          0.155286
# number        0.185645
# optimistic    0.371290
# roles         0.185645
# said          0.167886
# second        0.167886
# senior        0.185645
# shows         0.185645
# survey        0.185645
# that          0.124928
# the           0.230434
# they          0.167886
# this          0.100418
# year          0.185645
# Name: 34, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 36:
# POS tags: ['people', 'wish', 'your', 'vision', 'india', 'and', 'least', 'interested', 'about', 'your', 'personal', 'enmity', 'with', 'modi', 'others', 'its', 'your', 'personal', 'problem', 'handle', 'this', 'personally', 'and', 'dont', 'expect', 'nation', 'will', 'join', 'your', 'dirty', 'fight', 'with', 'others', 'tell', 'why', 'vote']
#      tfid
# about         0.116827
# and           0.156159
# dirty         0.157701
# dont          0.123610
# enmity        0.157701
# expect        0.157701
# fight         0.157701
# handle        0.157701
# india         0.088060
# interested    0.157701
# its           0.131912
# join          0.157701
# least         0.157701
# modi          0.049145
# nation        0.157701
# others        0.315402
# people        0.116827
# personal      0.315402
# personally    0.157701
# problem       0.157701
# tell          0.157701
# this          0.085303
# vision        0.142615
# vote          0.082736
# why           0.116827
# will          0.123610
# wish          0.157701
# with          0.203483
# your          0.527649
# Name: 35, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 37:
# POS tags: ['modi', 'for', 'eternal', 'what', 'wrong', 'dear', 'sirji', 'perfectly', 'fine', 'with', 'indian', 'people']
#      tfid
# dear         0.343164
# eternal      0.343164
# fine         0.343164
# for          0.169904
# indian       0.310337
# modi         0.106941
# people       0.254220
# perfectly    0.343164
# sirji        0.343164
# what         0.254220
# with         0.221394
# wrong        0.310337
# Name: 36, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 38:
# POS tags: ['impressive', 'godrej', 'tata', 'complimenting', 'our', 'hoping', 'gets', 'second', 'term']
#      tfid
# complimenting    0.348154
# gets             0.348154
# godrej           0.348154
# hoping           0.348154
# impressive       0.348154
# our              0.272892
# second           0.314850
# tata             0.348154
# term             0.314850
# Name: 37, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 39:
# POS tags: ['our', 'maid', 'saying', 'this', 'rahul', 'keeps', 'saying', 'modi', 'kalla', 'yet', 'goes', 'and', 'hugs', 'him', 'and', 'winks', 'magand', 'idu', 'bekagittu']
#      tfid
# and          0.242397
# bekagittu    0.244791
# goes         0.244791
# him          0.191874
# hugs         0.244791
# idu          0.244791
# kalla        0.244791
# keeps        0.244791
# magand       0.244791
# maid         0.244791
# modi         0.076285
# our          0.191874
# rahul        0.221375
# saying       0.442749
# this         0.132411
# winks        0.244791
# yet          0.244791
# Name: 38, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 40:
# POS tags: ['please', 'vote', 'for', 'modi', 'congress', 'trying', 'divide', 'india']
#      tfid
# congress    0.405050
# divide      0.484237
# for         0.239751
# india       0.270398
# modi        0.150904
# please      0.437916
# trying      0.437916
# vote        0.254050
# Name: 39, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 41:
# POS tags: ['yes', 'good', 'job', 'highly', 'insensitivearrogant', 'incompetent', 'ploar', 'needs', 'defeated', 'any', 'costnobody', 'knows', 'why', 'made', 'such', 'arrogant', 'person', 'minister', 'gave', 'tickethe', 'out', 'touch', 'with', 'grounddespite', '3months', 'upsc', 'protests', 'nvr', 'met']
#      tfid
# 3months                0.195541
# any                    0.176836
# arrogant               0.195541
# costnobody             0.195541
# defeated               0.195541
# gave                   0.195541
# good                   0.176836
# grounddespite          0.195541
# highly                 0.195541
# incompetent            0.195541
# insensitivearrogant    0.195541
# job                    0.163564
# knows                  0.195541
# made                   0.163564
# met                    0.195541
# minister               0.176836
# needs                  0.195541
# nvr                    0.195541
# out                    0.176836
# person                 0.195541
# ploar                  0.195541
# protests               0.195541
# such                   0.163564
# tickethe               0.195541
# touch                  0.176836
# upsc                   0.195541
# why                    0.144859
# with                   0.126154
# yes                    0.195541
# Name: 40, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 42:
# POS tags: ['before', '2014', 'hindustan', 'has', 'seen', 'the', 'worst', 'for', 'hindus', 'own', 'maj', 'hindu', 'rashtra', 'who', 'thrashed', 'the', 'rascal', 'faces', 'these', 'anti', 'indian', 'politiciansantinationals', 'urban', 'naxals', 'wait', 'watch', 'after', 'modis', 'win', 'pakistan', 'mein', 'bhi', 'hindu', 'hona', 'garv', 'baat', 'hogi✌']
#      tfid
# 2014                        0.170955
# after                       0.170955
# anti                        0.154602
# baat                        0.170955
# before                      0.170955
# bhi                         0.170955
# faces                       0.170955
# for                         0.084641
# garv                        0.170955
# has                         0.115043
# hindu                       0.341910
# hindus                      0.154602
# hindustan                   0.170955
# hogi                        0.170955
# hona                        0.170955
# indian                      0.154602
# maj                         0.170955
# mein                        0.170955
# modis                       0.126645
# naxals                      0.170955
# own                         0.154602
# pakistan                    0.154602
# politiciansantinationals    0.170955
# rascal                      0.170955
# rashtra                     0.170955
# seen                        0.170955
# the                         0.141467
# these                       0.142999
# thrashed                    0.170955
# urban                       0.170955
# wait                        0.170955
# watch                       0.170955
# who                         0.120428
# win                         0.170955
# worst                       0.170955
# Name: 41, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 43:
# POS tags: ['higher', 'voting', 'turnout', 'directly', 'proportional', 'bjp', 'victory', 'wonder', 'modi', 'has', 'launched', 'campaigns', 'like', 'dont', 'sit', 'home', 'ensure', 'everyone', 'your', 'friends', 'family', 'relatives', 'votes', 'its', 'now', 'never', 'for']
#      tfid
# bjp             0.166153
# campaigns       0.211977
# directly        0.211977
# dont            0.166153
# ensure          0.177312
# everyone        0.211977
# family          0.191699
# for             0.104952
# friends         0.211977
# has             0.142648
# higher          0.211977
# home            0.211977
# its             0.177312
# launched        0.211977
# like            0.177312
# modi            0.066059
# never           0.211977
# now             0.166153
# proportional    0.211977
# relatives       0.211977
# sit             0.211977
# turnout         0.211977
# victory         0.211977
# votes           0.211977
# voting          0.211977
# wonder          0.211977
# your            0.177312
# Name: 42, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 44:
# POS tags: ['modi', 'govt', 'has', 'done', 'remarkable', 'job', 'making', 'corruption', 'free', 'india', 'ultimate', 'success', 'shall', 'achieved', 'when', 'corrupt', 'are', 'jailed', 'modi', 'govts', 'vision', 'corruptionfree', 'india', 'ensuring', 'that', 'all', 'those', 'who', 'looted', 'the', 'country', 'are', 'now', 'facing', 'the', 'law', 'via', 'namo', 'app']
#      tfid
# achieved          0.179472
# all               0.132955
# app               0.179472
# are               0.241548
# corrupt           0.179472
# corruption        0.179472
# corruptionfree    0.179472
# country           0.179472
# done              0.179472
# ensuring          0.179472
# facing            0.179472
# free              0.179472
# govt              0.140675
# govts             0.162304
# has               0.120774
# india             0.200434
# jailed            0.179472
# job               0.150123
# law               0.179472
# looted            0.179472
# making            0.179472
# modi              0.111858
# namo              0.179472
# now               0.140675
# remarkable        0.179472
# shall             0.179472
# success           0.179472
# that              0.120774
# the               0.148515
# those             0.150123
# ultimate          0.179472
# via               0.150123
# vision            0.162304
# when              0.179472
# who               0.126428
# Name: 43, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 45:
# POS tags: ['use', 'this', 'beg', 'for', 'campaign']
#      tfid
# beg         0.572107
# campaign    0.478551
# for         0.283256
# this        0.309462
# use         0.517380
# Name: 44, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 46:
# POS tags: ['with', 'welfare', 'delivery', 'gst', 'ibc', 'and', 'feo', 'place', 'modi', 'can', 'exit', 'psus', '2nd', 'term', 'and', 'use', 'that', 'money', 'appoint', 'more', 'judges', 'police', 'forensic', 'labs', 'and', 'fasttrack', 'delivery', 'justice', 'education', 'and', 'healthcare', 'citizens', 'and', 'invest', 'defence', 'india', 'well']
#      tfid
# 2nd           0.167109
# and           0.413687
# appoint       0.167109
# can           0.130985
# citizens      0.167109
# defence       0.167109
# delivery      0.334218
# education     0.151124
# exit          0.167109
# fasttrack     0.167109
# feo           0.167109
# forensic      0.167109
# gst           0.151124
# healthcare    0.167109
# ibc           0.167109
# india         0.093314
# invest        0.167109
# judges        0.167109
# justice       0.167109
# labs          0.167109
# modi          0.052077
# money         0.167109
# more          0.151124
# place         0.167109
# police        0.167109
# psus          0.167109
# term          0.151124
# that          0.112455
# use           0.151124
# welfare       0.167109
# well          0.139782
# with          0.107811
# Name: 45, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 47:
# POS tags: ['this', 'the', 'new', 'india', 'modi', 'trying', 'build', 'with', 'these', 'leaders', 'his', 'party', 'why', 'have', 'live', 'with', 'these', 'deplorable', 'characters']
#      tfid
# build         0.259632
# characters    0.259632
# deplorable    0.259632
# have          0.217175
# his           0.203506
# india         0.144978
# leaders       0.259632
# live          0.259632
# modi          0.080910
# new           0.259632
# party         0.234796
# the           0.107424
# these         0.434349
# this          0.140439
# trying        0.234796
# why           0.192339
# with          0.335005
# Name: 46, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 48:
# POS tags: ['not', 'just', 'healing', 'touch', 'india', 'need', 'surgery', 'remove', 'the', 'cancer', 'spread', 'modi', 'and', 'rss']
#      tfid
# and        0.162226
# cancer     0.327657
# healing    0.327657
# india      0.182964
# just       0.274076
# modi       0.102108
# need       0.256826
# not        0.195877
# remove     0.327657
# rss        0.327657
# spread     0.327657
# surgery    0.327657
# the        0.135570
# touch      0.296314
# Name: 47, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 49:
# POS tags: ['mistry', 'man', 'not', 'then', 'why', 'drag', 'modi', 'the', 'nri', 'followers', 'this', 'the', 'man', 'wrong', 'action', 'should', 'taken', 'against', 'him', 'for', 'spreading', 'hatred', 'please', 'don', '’', 'have', 'agenda', 'condemning', 'criminal', 'activities', 'sir', 'fyi', 'please']
#      tfid
# action        0.171764
# activities    0.189933
# against       0.140704
# agenda        0.189933
# condemning    0.189933
# criminal      0.189933
# don           0.189933
# drag          0.189933
# followers     0.189933
# for           0.094038
# fyi           0.189933
# hatred        0.189933
# have          0.158873
# him           0.148874
# man           0.343528
# mistry        0.189933
# modi          0.059189
# not           0.113544
# nri           0.189933
# please        0.343528
# should        0.171764
# sir           0.171764
# spreading     0.189933
# taken         0.171764
# the           0.157171
# then          0.189933
# this          0.102738
# why           0.140704
# wrong         0.171764
# Name: 48, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# Document 50:
# POS tags: ['think', 'you', 'forgot', 'dollar', 'india', 'handled', 'exceptionally', 'well', 'and', 'one', 'the', 'diplomatic', 'shrewdness', 'and', 'achievement', 'why', 'you', 'always', 'undermine', 'modi', 'government', 'you', 'are', 'always', 'prone', 'criticise', 'even', 'without', 'considering', 'other', 'aspects']
#      tfid
# achievement      0.183271
# always           0.366541
# and              0.181478
# are              0.123330
# aspects          0.183271
# considering      0.183271
# criticise        0.183271
# diplomatic       0.183271
# dollar           0.183271
# even             0.183271
# exceptionally    0.183271
# forgot           0.183271
# government       0.183271
# handled          0.183271
# india            0.102338
# modi             0.057113
# one              0.135769
# other            0.143652
# prone            0.183271
# shrewdness       0.183271
# the              0.075829
# think            0.165739
# undermine        0.183271
# well             0.153300
# why              0.135769
# without          0.183271
# you              0.430957
# Name: 49, dtype: float64
#
# ---------------xxxxxxxxxxxxxxxxxxxxx--------------------
# overall cosine similarity
#         2014      2019       2nd   3months     about    abuses  according  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.178064   0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 12  0.000000  0.208476  0.000000  0.000000  0.000000  0.000000   0.000000
# 13  0.000000  0.221767  0.000000  0.000000  0.000000  0.000000   0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 16  0.000000  0.243434  0.000000  0.000000  0.000000  0.000000   0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.122675  0.000000   0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.130324  0.000000   0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.298369  0.000000   0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.432845
# 26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 28  0.000000  0.226166  0.000000  0.000000  0.000000  0.000000   0.000000
# 29  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 32  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 34  0.000000  0.000000  0.000000  0.000000  0.275056  0.000000   0.000000
# 35  0.000000  0.000000  0.000000  0.000000  0.116827  0.000000   0.000000
# 36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 37  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 38  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 40  0.000000  0.000000  0.000000  0.195541  0.000000  0.000000   0.000000
# 41  0.170955  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 43  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 44  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 45  0.000000  0.000000  0.167109  0.000000  0.000000  0.000000   0.000000
# 46  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 47  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 48  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 49  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#     achieved  achievement    action  ...     would   written     wrong  \
# 0   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 4   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 5   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 6   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 7   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8   0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 9   0.000000     0.000000  0.000000  ...  0.153246  0.000000  0.000000
# 10  0.000000     0.000000  0.000000  ...  0.242074  0.000000  0.000000
# 11  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 12  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 13  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 14  0.000000     0.000000  0.222900  ...  0.000000  0.000000  0.000000
# 15  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 16  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 17  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 18  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 19  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 20  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 21  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 22  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 23  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 24  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 25  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 26  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 27  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 28  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 29  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 30  0.000000     0.000000  0.000000  ...  0.000000  0.176899  0.000000
# 31  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 32  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 33  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 34  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 35  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 36  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.310337
# 37  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 38  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 39  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 40  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 41  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 42  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 43  0.179472     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 44  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 45  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 46  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 47  0.000000     0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 48  0.000000     0.000000  0.171764  ...  0.000000  0.000000  0.171764
# 49  0.000000     0.183271  0.000000  ...  0.000000  0.000000  0.000000
#
#        yagna      year       yes       yet      yogi       you      your
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.196892  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.316916  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.259596  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.137891  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.296368
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.216423  0.000000  0.000000
# 26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 29  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 34  0.000000  0.185645  0.000000  0.000000  0.000000  0.000000  0.000000
# 35  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.527649
# 36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 37  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 38  0.000000  0.000000  0.000000  0.244791  0.000000  0.000000  0.000000
# 39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 40  0.000000  0.000000  0.195541  0.000000  0.000000  0.000000  0.000000
# 41  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.177312
# 43  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 44  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 45  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 46  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 47  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 48  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 49  0.000000  0.000000  0.000000  0.000000  0.000000  0.430957  0.000000
#
# [50 rows x 573 columns]
# cosine similarity for all docs
# [[1.         0.12293116 0.04431094 ... 0.07845823 0.06822424 0.05959746]
#  [0.12293116 1.         0.11796872 ... 0.1532445  0.09264438 0.1437955 ]
#  [0.04431094 0.11796872 1.         ... 0.02651693 0.01537104 0.01794752]
#  ...
#  [0.07845823 0.1532445  0.02651693 ... 1.         0.04959193 0.0642765 ]
#  [0.06822424 0.09264438 0.01537104 ... 0.04959193 1.         0.03440188]
#  [0.05959746 0.1437955  0.01794752 ... 0.0642765  0.03440188 1.        ]]
# (50, 50)

# %% [markdown]
# # **3C - POSTAGS**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

text = "The quick brown fox jumps over the lazy dog"

tokens = word_tokenize(text)
pos_tags = pos_tag(tokens)

for word, tag in pos_tags:
    print(f"{word}: {tag}")
# Out:
# The: DT
# quick: JJ
# brown: NN
# fox: NN
# jumps: VBZ
# over: IN
# the: DT
# lazy: JJ
# dog: NN
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
