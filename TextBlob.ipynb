# %% [markdown]
# ## **WORD AND SENTENCE TOKENIZE**

# %%
from textblob import TextBlob

# %%
text_file = open("/content/sample.txt")
text = text_file.read()

# %%
print(type(text))
print("\n")
print(text)
print("\n")
print(len(text))
# Out:
# <class 'str'>
#
#
# Businesses use natural language processing (NLP) software and tools to simplify, automate, and streamline operations efficiently and accurately. We give some example use cases below.
#
# Sensitive data redaction
#
# Businesses in the insurance, legal, and healthcare sectors process, sort, and retrieve large volumes of sensitive documents like medical records, financial data, and private data. Instead of reviewing manually, companies use NLP technology to redact personally identifiable information and protect sensitive data. For example, Chisel AI helps insurance carriers extract policy numbers, expiration dates, and other personal customer attributes from unstructured documents with Amazon Comprehend.
#
# Customer engagement
#
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# create a TextBlob object
blob_object = TextBlob(text)

# tokenize paragraph into words.
print(" Word Tokenize :\n", blob_object.words)

# tokenize paragraph into sentences.
print("\n Sentence Tokenize :\n", blob_object.sentences)
# Out:
#  Word Tokenize :
# ...

# %% [markdown]
# ## **FREQUENCY DISTRIBUTION**

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

# Example text
# text = "This is an example sentence. Another sentence for demonstration purposes."

# Create a TextBlob object
blob = TextBlob(text)

# Get word frequencies
word_frequencies = blob.word_counts

# Sort the words and frequencies in descending order of frequencies
sorted_word_frequencies = sorted(word_frequencies.items(), key=lambda x: x[1], reverse=True)

# Extract words and their frequencies
words = [word for word, _ in sorted_word_frequencies]
frequencies = [freq for _, freq in sorted_word_frequencies]

# Plot the word frequencies as a line graph
plt.figure(figsize=(10, 6))
plt.plot(words, frequencies, marker='o')
plt.xticks(rotation=45)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Word Frequency Line Graph')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **LEMMETIZATION**

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# from textblob lib import Word method
from textblob import Word

# create a Word object.
u = Word("rocks")

# apply lemmatization.
print("rocks :", u.lemmatize())

# create a Word object.
v = Word("corpora")

# apply lemmatization.
print("corpora :", v.lemmatize())

# create a Word object.
w = Word("better")

# apply lemmatization with
# parameter "a", "a" denotes adjective.
print("better :", w.lemmatize("a"))
# Out:
# rocks : rock
# corpora : corpus
# better : good

# %% [markdown]
# ## **SENTENCE CORRECTION**

# %%
# import TextBlob
from textblob import TextBlob

gfg = TextBlob("Natural Languge Procesing")

# using TextBlob.correct() method
gfg = gfg.correct()

print(gfg)
# Out:
# Natural Language Processing

# %% [markdown]
# ## **PARTS OF SPEECH**

# %%
 import nltk
 nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# from textblob lib import TextBlob method
from textblob import TextBlob

# create a textblob object
blob_object = TextBlob(text)

# Part-of-speech tags can be accessed
# through the tags property of blob object.'

# print word with pos tag.
print(blob_object.tags)
# Out:
# [('Businesses', 'NNS'), ('use', 'VBP'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('NLP', 'NNP'), ('software', 'NN'), ('and', 'CC'), ('tools', 'NNS'), ('to', 'TO'), ('simplify', 'VB'), ('automate', 'VB'), ('and', 'CC'), ('streamline', 'VB'), ('operations', 'NNS'), ('efficiently', 'RB'), ('and', 'CC'), ('accurately', 'RB'), ('We', 'PRP'), ('give', 'VBP'), ('some', 'DT'), ('example', 'NN'), ('use', 'NN'), ('cases', 'NNS'), ('below', 'IN'), ('Sensitive', 'JJ'), ('data', 'NNS'), ('redaction', 'NN'), ('Businesses', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('insurance', 'NN'), ('legal', 'JJ'), ('and', 'CC'), ('healthcare', 'JJ'), ('sectors', 'NNS'), ('process', 'NN'), ('sort', 'NN'), ('and', 'CC'), ('retrieve', 'VB'), ('large', 'JJ'), ('volumes', 'NNS'), ('of', 'IN'), ('sensitive', 'JJ'), ('documents', 'NNS'), ('like', 'IN'), ('medical', 'JJ'), ('records', 'NNS'), ('financial', 'JJ'), ('data', 'NN'), ('and', 'CC'), ('private', 'JJ'), ('data', 'NNS'), ('Instead', 'RB'), ('of'
# ...

# %% [markdown]
# ## **NOUN PHRASES**

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
# import TextBlob
from textblob import TextBlob

gfg = TextBlob(text)

# using TextBlob.noun_phrases method
gfg = gfg.noun_phrases

print(gfg)
# Out:
# ['businesses', 'natural language processing', 'nlp', 'streamline operations', 'example use cases', 'sensitive', 'data redaction', 'businesses', 'healthcare sectors process', 'large volumes', 'sensitive documents', 'medical records', 'financial data', 'private data', 'nlp', 'identifiable information', 'sensitive data', 'chisel ai', 'insurance carriers extract policy numbers', 'expiration dates', 'personal customer attributes', 'amazon comprehend', 'customer', 'nlp', 'voice bots', 'businesses', 'scale customer service capability', 'operational costs', 'pubnub', 'builds chatbot software', 'amazon comprehend', 'global customers', 't-mobile', 'nlp', 'specific keywords', 'text messages', 'oklahoma', 'state university deploys', 'chatbot solution', 'address student questions', 'machine learning technology', 'business analytics', 'marketers', 'nlp', 'amazon comprehend', 'amazon lex', "company 's product", 'specific phrases', 'kpi', 'natural language processing solutions', 'businesses focus', 
# ...

# %% [markdown]
# ## **PUNCTUATION REMOVAL**

# %%
from textblob import TextBlob

# Example text
# text = "Hello, world! How are you today?"

# Create a TextBlob object
blob = TextBlob(text)

# Remove punctuation from each word
filtered_text = " ".join([Word(word).strip().strip('.!?,:;"\'') for word in blob.words])

# Print the filtered text
print(filtered_text)
# Out:
# Businesses use natural language processing NLP software and tools to simplify automate and streamline operations efficiently and accurately We give some example use cases below Sensitive data redaction Businesses in the insurance legal and healthcare sectors process sort and retrieve large volumes of sensitive documents like medical records financial data and private data Instead of reviewing manually companies use NLP technology to redact personally identifiable information and protect sensitive data For example Chisel AI helps insurance carriers extract policy numbers expiration dates and other personal customer attributes from unstructured documents with Amazon Comprehend Customer engagement NLP technologies allow chat and voice bots to be more human-like when conversing with customers Businesses use chatbots to scale customer service capability and quality while keeping operational costs to a minimum PubNub which builds chatbot software uses Amazon Comprehend to introduce localiz
# ...

# %% [markdown]
# ## **STOPWORDS REMOVAL**

# %%
pip install textblob nltk

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Example text
# text = "This is an example sentence with stop words that should be removed."

# Tokenize the text
tokens = word_tokenize(text)

# Remove stop words from the tokens
filtered_tokens = [word for word in tokens if word.lower() not in stopwords.words('english')]

# Join the filtered tokens back into a string
filtered_text = " ".join(filtered_tokens)

# Print the filtered text
print(filtered_text)
# Out:
# Businesses use natural language processing ( NLP ) software tools simplify , automate , streamline operations efficiently accurately . give example use cases . Sensitive data redaction Businesses insurance , legal , healthcare sectors process , sort , retrieve large volumes sensitive documents like medical records , financial data , private data . Instead reviewing manually , companies use NLP technology redact personally identifiable information protect sensitive data . example , Chisel AI helps insurance carriers extract policy numbers , expiration dates , personal customer attributes unstructured documents Amazon Comprehend . Customer engagement NLP technologies allow chat voice bots human-like conversing customers . Businesses use chatbots scale customer service capability quality keeping operational costs minimum . PubNub , builds chatbot software , uses Amazon Comprehend introduce localized chat functionality global customers . T-Mobile uses NLP identify specific keywords custo
# ...

# %% [markdown]
# ## **FINAL FREQUENCY DISTRIBUTION**

# %%
from textblob import TextBlob
from nltk import FreqDist
import matplotlib.pyplot as plt

# Example text
# text = "This is an example sentence. Another sentence for demonstration purposes."

# Create a TextBlob object
blob = TextBlob(text)

# Tokenize the text into words
words = blob.words

# Create a frequency distribution of words
freq_dist = FreqDist(words)

# Plot the frequency distribution
plt.figure(figsize=(10, 6))
freq_dist.plot(30, cumulative=False)
# plt.xlabel('Words')
# plt.ylabel('Frequency')
# plt.title('Word Frequency Distribution')
plt.show()

# %% [markdown]
# ## **STEMMING**

# %%
from textblob import TextBlob
from nltk.stem import PorterStemmer

# Example text
text = "This is an example sentence with running, runner, and runs."

# Create a TextBlob object
blob = TextBlob(text)

# Initialize Porter stemmer from NLTK
stemmer = PorterStemmer()

# Perform stemming on each word
stemmed_words = [stemmer.stem(word) for word in blob.words]

# Join the stemmed words into a sentence
stemmed_sentence = " ".join(stemmed_words)

# Print the stemmed sentence
print(stemmed_sentence)
# Out:
# thi is an exampl sentenc with run runner and run

# %% [markdown]
# ## **SENTIMENT ANALYSIS**

# %%
# import TextBlob
from textblob import TextBlob

gfg = TextBlob("Recession is very bad and many are not getting placed")

# using TextBlob.sentiment method
gfg = gfg.sentiment

print(gfg)
# Out:
# Sentiment(polarity=-0.2049999999999999, subjectivity=0.6833333333333333)

# %%
# https://www.geeksforgeeks.org/python-tokenize-text-using-textblob/
# https://www.geeksforgeeks.org/python-lemmatization-with-textblob/
# https://www.geeksforgeeks.org/python-textblob-word_counts-method/
# https://www.geeksforgeeks.org/python-part-of-speech-tagging-using-textblob/
# https://www.geeksforgeeks.org/python-textblob-noun_phrases-method/
# https://www.geeksforgeeks.org/python-textblob-correct-method/
# https://www.geeksforgeeks.org/python-textblob-sentiment-method/
# https://chat.openai.com/share/9d2e2390-0904-4a23-8aed-d3abfa3f1d6d
